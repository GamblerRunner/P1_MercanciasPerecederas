# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import folium

# %%
df_order_historic_demand = pd.read_excel('../../Datos_P1/df_historic_order_demand.xlsx')
df_distances = pd.read_excel('../../Datos_P1/df_distance_km.xlsx')
df_distance_min = pd.read_excel('../../Datos_P1/df_distance_min.xlsx')
df_location = pd.read_excel('../../Datos_P1/df_location.xlsx')
df_customers = pd.read_excel('../../Datos_P1/df_orders.xlsx')
df_vehicles = pd.read_excel('../../Datos_P1/df_vehicle.xlsx')

# %%
# Diferencia clave para Caso 2
df_vehicles = df_vehicles.sample(n=1, random_state=42) 
print(df_vehicles)
# Out:
#    vehiculo_id  capacidad_kg  costo_km  autonomia_km
# 0            1          2026       0.2           603

# %%
#cambiar posicion de almacen por mas comodidad

# Mostrar las primeras filas para verificar el contenido original
print("Datos originales:")
print(df_distances.head())
# Out:
# Datos originales:
#    Cliente_1  Cliente_2  Cliente_3  Cliente_4  Cliente_5  Cliente_6  \
# 0     0.0000     7.5625    15.5365     1.1998     4.7145     1.7407
# 1     7.5625     0.0000     3.3838     7.7433    14.5720     8.5237
# 2    15.5365     3.3838     0.0000    12.5438     0.0000     0.0000
# 3     1.1998     7.7433    12.5438     0.0000     5.0721     0.9119
# 4     4.7145    14.5720     0.0000     5.0721     0.0000     4.8187
#
#    Cliente_7  Cliente_8  Cliente_9  Cliente_10  ...  Cliente_12  Cliente_13  \
# 0     7.9408    17.1947     4.2933      3.2659  ...      6.0225      5.4470
# 1     0.4847    13.7974    10.1522      7.1521  ...     10.1049      2.6961
# 2     0.0000    16.0355    13.9120     13.0649  ...     12.3430      5.0114
# 3     7.5798    17.4095     3.5781      3.3451  ...      6.2330      4.7117
# 4     0.0000     0.0000     0.0000      7.2170  ...      6.8738      9.1064
#
#    Cliente_14  Cliente_15  Cliente_16  Cliente_17  Cliente_18  Cliente_19  \
# 0      2.2133     11.1505      1.5775     10.8288      9.1456     20.4871
# 1     13.4907     18.0835      7.0275     19.8218      8.2737      9.6369
# 2     15.7289     17.9217      9.6824     22.0599     10.5118      7.7574
# 3      2.8799     11.3610      1.3127     11.1926      9.3561     20.7019
# 4      3.6476     12.0019      5.4347      5.2872      9.9969     21.3384
#
#    Cliente_20  Almacén
# 0     22.1445   3.6114
# 1     19.1038  10.7361
# 2     16.5997  13.9021
# 3     21.1518   3.3673
# 4     25.5947   4.5417
#
# [5 rows x 21 columns]

# %%
def calculo_Probabilidad(current_node, unvisited_nodes, pheromones, df_distances):
    #Estas dos variables imprescindibles para ACO
    alpha = 1.0
    beta = 2.0
    probabilities = []
    for node in unvisited_nodes:
        distance = df_distances.iloc[current_node, node]
        if distance > 0:  
            tau = pheromones[current_node][node] ** alpha
            eta = (1 / distance) ** beta
            probabilities.append(tau * eta)
        else:
            probabilities.append(0)  
    
    probabilities = np.array(probabilities)
    total = probabilities.sum()
    
    # Evitar misma posicion entre clientes 
    if total == 0:
        probabilities = np.ones(len(unvisited_nodes)) / len(unvisited_nodes)
    else:
        probabilities = probabilities / total
    
    return probabilities

# %%
def calculo_Coste(solution, df_distances, df_vehicles):
    total_cost = 0
    vehicle_costes = []
    for vehicle_name, routes in solution:
        vehicle = df_vehicles.loc[df_vehicles["vehiculo_id"] == vehicle_name]
        price_per_km = vehicle["costo_km"].values[0]
        vehicle_total = 0
        
        for route in routes:
            route_cost = sum(df_distances.iloc[route[i], route[i + 1]] for i in range(len(route) - 1))
            vehicle_total += route_cost * price_per_km
        total_cost += vehicle_total
        vehicle_costes.append((vehicle_name, vehicle_total))
    return total_cost, vehicle_costes

# %%
def solucion_Vehiculo(df_distances, df_vehicles_shuffled, orders,pheromone_matrix, autonomia_restante=None):
    solution = []
    remaining_customers = set(range(20))
    depot = 20

    if autonomia_restante is None:
        autonomia_restante = {row["vehiculo_id"]: row["autonomia_km"] for _, row in df_vehicles_shuffled.iterrows()}

    for _, vehicle in df_vehicles_shuffled.iterrows():  # Usar el DataFrame reordenado
        vehicle_id = vehicle["vehiculo_id"]
        vehicle_routes = []
        vehicle_capacity = vehicle["capacidad_kg"]
        current_autonomy = autonomia_restante[vehicle_id]

        while remaining_customers and current_autonomy > 0:
            current_route = [depot]  # Inicia en el almacén
            current_capacity = vehicle_capacity
            current_node = depot
            total_distance = 0

            while remaining_customers:
                unvisited_nodes = [
                    node for node in remaining_customers
                    if orders[node] <= current_capacity 
                    and (total_distance + df_distances.iloc[current_node, node] + df_distances.iloc[node, depot]) <= current_autonomy
                ]

                if not unvisited_nodes:
                    break

                probabilities = calculo_Probabilidad(current_node, unvisited_nodes, pheromone_matrix, df_distances)
                next_node = np.random.choice(unvisited_nodes, p=probabilities)

                distance_to_next = df_distances.iloc[current_node, next_node]
                total_distance += distance_to_next
                current_autonomy -= distance_to_next

                current_route.append(next_node)
                current_capacity -= orders[next_node]
                remaining_customers.remove(next_node)
                current_node = next_node

            # Verificar si se agregaron clientes a la ruta
            if len(current_route) == 1:  # Solo el almacén, no hay clientes
                break  # Salir del bucle externo para este vehículo
            else:
                # Regresar al almacén y actualizar autonomía
                distance_to_depot = df_distances.iloc[current_node, depot]
                current_autonomy -= distance_to_depot
                current_route.append(depot)
                if len(current_route) > 2:
                    vehicle_routes.append(current_route)

            # Actualizar autonomía restante después de cada ruta
            autonomia_restante[vehicle_id] = current_autonomy

        if vehicle_routes:
            solution.append((vehicle_id, vehicle_routes))

    return solution, autonomia_restante

# %%
# Parámetros de ACO
num_vehiculos = 10
num_iterations = 100
rho = 0.5
Q = 100

n_nodes = len(df_customers)+1
pheromone_matrix = np.ones((n_nodes, n_nodes))
n_nodes = len(df_customers)+1
pheromone_matrix = np.ones((n_nodes, n_nodes))

solucion_optima = None
mejor_precio = float('inf')

for iteration in range(num_iterations):
    # Reordenar aleatoriamente los vehículos en cada iteración
    df_vehicles_shuffled = df_vehicles.sample(frac=1).reset_index(drop=True)

    soluciones = []
    costes = []

    for _ in range(num_vehiculos):
        solution, _ = solucion_Vehiculo(df_distances, df_vehicles_shuffled, df_customers["order_demand"],pheromone_matrix, None)
        total_cost, _ = calculo_Coste(solution, df_distances, df_vehicles_shuffled)
        soluciones.append(solution)
        costes.append(total_cost)

        if total_cost < mejor_precio:
            mejor_precio = total_cost
            solucion_optima = solution

    # Actualizar feromonas
    pheromone_matrix *= (1 - rho)
    for solution, cost in zip(soluciones, costes):
        for vehicle_name, routes in solution:
            for route in routes:
                for i in range(len(route) - 1):
                    pheromone_matrix[route[i]][route[i + 1]] += Q / cost

print(solucion_optima, mejor_precio)
# Out:
# [(np.float64(1.0), [[20, np.int64(0), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(13), np.int64(10), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(12), np.int64(19), 20]])] 46.745720000000006

# %%
#Este es exactamente igual a la celda anterior pero para demostrar lka evoluciñon de las iteraciones con sus rutas
# Output
for iteration in range(num_iterations):
    print(f"\n🔄 Iteración {iteration + 1} 🔄")

    # Reordenar aleatoriamente los vehículos en cada iteración
    df_vehicles_shuffled = df_vehicles.sample(frac=1).reset_index(drop=True)

    soluciones = []
    costes = []

    for vehiculo_idx in range(num_vehiculos):
        solution, _ = solucion_Vehiculo(df_distances, df_vehicles_shuffled, df_customers["order_demand"], pheromone_matrix, None)
        total_cost, _ = calculo_Coste(solution, df_distances, df_vehicles_shuffled)
        soluciones.append(solution)
        costes.append(total_cost)

        # Imprimir detalle de la solución del vehículo
        print(f"\n🚚 Ruta {vehiculo_idx + 1}:")
        for vehicle_id, routes in solution:
            print(f"  Vehículo {vehicle_id} - Rutas: {routes}")
        print(f"  Costo total: {total_cost:.2f}")

        # Actualizar mejor solución
        if total_cost < mejor_precio:
            mejor_precio = total_cost
            solucion_optima = solution

    # Actualizar feromonas
    pheromone_matrix *= (1 - rho)
    for solution, cost in zip(soluciones, costes):
        for vehicle_name, routes in solution:
            for route in routes:
                for i in range(len(route) - 1):
                    pheromone_matrix[route[i]][route[i + 1]] += Q / cost

# Imprimir mejor solución encontrada
print("\n✅ Mejor solución encontrada:")
print(solucion_optima)
print(f"💰 Mejor precio: {mejor_precio:.2f}")
# Out:
# 🔄 Iteración 1 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(7), np.int64(18), 20]]
#   Costo total: 47.34
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 50.28
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(17), np.int64(18), 20], [20, np.int64(12), np.int64(19), 20]]
#   Costo total: 49.69
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(2), np.int64(7), 20], [20, np.int64(19), np.int64(14), 20]]
#   Costo total: 53.27
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(12), np.int64(18), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(19), 20], [20, np.int64(7), np.int64(14), 20]]
#   Costo total: 48.16
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(12), np.int64(14), 20], [20, np.int64(18), np.int64(7), 20], [20, np.int64(2), np.int64(19), 20]]
#   Costo total: 49.31
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 50.28
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(12), np.int64(1), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(18), 20]]
#   Costo total: 48.35
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(18), 20], [20, np.int64(2), np.int64(19), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 49.49
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(0), np.int64(18), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(12), np.int64(7), 20]]
#   Costo total: 50.21
#
# 🔄 Iteración 2 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(7), np.int64(18), 20]]
#   Costo total: 47.34
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(17), np.int64(19), 20]]
#   Costo total: 50.49
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(2), np.int64(7), 20], [20, np.int64(19), np.int64(14), 20], [20, np.int64(12), np.int64(18), 20]]
#   Costo total: 53.55
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(0), np.int64(18), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(19), np.int64(6), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(17), np.int64(2), 20]]
#   Costo total: 50.31
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(12), np.int64(18), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.46
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(12), np.int64(7), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(19), np.int64(6), 20], [20, np.int64(14), np.int64(18), 20]]
#   Costo total: 50.87
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(15), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(19), np.int64(6), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(17), np.int64(11), 20]]
#   Costo total: 46.87
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(7), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20]]
#   Costo total: 48.37
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(2), np.int64(19), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(17), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.72
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(12), np.int64(18), 20]]
#   Costo total: 47.26
#
# 🔄 Iteración 3 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(10), np.int64(13), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(19), np.int64(17), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 48.52
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(18), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(11), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(19), np.int64(2), 20]]
#   Costo total: 50.75
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(9), np.int64(11), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(18), 20]]
#   Costo total: 47.32
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(2), np.int64(19), 20], [20, np.int64(18), np.int64(7), 20]]
#   Costo total: 47.34
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(0), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(18), np.int64(7), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(6), np.int64(19), 20], [20, np.int64(14), np.int64(17), 20]]
#   Costo total: 50.03
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(2), np.int64(7), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(19), np.int64(6), 20], [20, np.int64(18), np.int64(11), 20]]
#   Costo total: 50.64
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(2), np.int64(19), 20], [20, np.int64(18), np.int64(11), 20]]
#   Costo total: 48.28
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(12), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(7), np.int64(14), 20]]
#   Costo total: 47.87
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(7), np.int64(11), 20]]
#   Costo total: 48.45
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(19), np.int64(18), 20]]
#   Costo total: 50.09
#
# 🔄 Iteración 4 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(18), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(7), np.int64(14), 20]]
#   Costo total: 49.31
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(7), np.int64(14), 20]]
#   Costo total: 47.38
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(19), np.int64(6), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(2), np.int64(18), 20]]
#   Costo total: 46.87
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(12), np.int64(14), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 52.25
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(17), np.int64(18), 20]]
#   Costo total: 48.35
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(0), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(19), np.int64(6), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(7), np.int64(18), 20]]
#   Costo total: 50.03
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(17), np.int64(19), 20], [20, np.int64(6), np.int64(18), 20]]
#   Costo total: 48.48
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(9), np.int64(11), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 49.28
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(12), np.int64(1), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(19), np.int64(17), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(2), np.int64(18), 20]]
#   Costo total: 48.52
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(2), np.int64(19), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(6), np.int64(18), 20]]
#   Costo total: 47.38
#
# 🔄 Iteración 5 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(17), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 48.35
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(18), np.int64(11), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(6), np.int64(19), 20], [20, np.int64(12), np.int64(17), 20]]
#   Costo total: 48.99
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(18), 20], [20, np.int64(6), np.int64(1), 20]]
#   Costo total: 47.32
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(4), np.int64(16), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(6), np.int64(19), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 46.87
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(2), np.int64(19), 20]]
#   Costo total: 47.38
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(6), np.int64(7), 20], [20, np.int64(2), np.int64(14), 20]]
#   Costo total: 52.51
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 50.31
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 49.28
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(6), np.int64(19), 20]]
#   Costo total: 46.87
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(7), 20], [20, np.int64(2), np.int64(14), 20]]
#   Costo total: 53.28
#
# 🔄 Iteración 6 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(6), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(7), np.int64(11), 20]]
#   Costo total: 48.15
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(2), np.int64(19), 20]]
#   Costo total: 47.17
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 52.28
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(15), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(19), 20], [20, np.int64(17), np.int64(11), 20]]
#   Costo total: 46.87
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(6), np.int64(1), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(12), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.87
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(17), np.int64(11), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(19), np.int64(18), 20]]
#   Costo total: 50.09
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(10), np.int64(13), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(19), np.int64(7), 20], [20, np.int64(2), np.int64(11), 20]]
#   Costo total: 51.97
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(17), np.int64(19), 20], [20, np.int64(2), np.int64(18), 20]]
#   Costo total: 47.49
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 50.31
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(17), np.int64(19), 20]]
#   Costo total: 47.49
#
# 🔄 Iteración 7 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(4), np.int64(16), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(2), np.int64(19), 20], [20, np.int64(17), np.int64(11), 20]]
#   Costo total: 47.17
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(12), np.int64(14), 20], [20, np.int64(19), np.int64(7), 20], [20, np.int64(17), np.int64(11), 20]]
#   Costo total: 50.64
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(18), np.int64(7), 20], [20, np.int64(2), np.int64(19), 20]]
#   Costo total: 47.34
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(0), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(17), np.int64(2), 20], [20, np.int64(19), np.int64(18), 20]]
#   Costo total: 47.99
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(12), np.int64(17), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 49.28
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(2), np.int64(19), 20], [20, np.int64(17), np.int64(11), 20]]
#   Costo total: 47.17
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(10), np.int64(13), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(19), np.int64(7), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(12), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(14), np.int64(18), 20], [20, np.int64(6), np.int64(11), 20]]
#   Costo total: 53.63
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20]]
#   Costo total: 47.38
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(7), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(2), np.int64(14), 20]]
#   Costo total: 51.90
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(15), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(12), np.int64(18), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(7), np.int64(11), 20]]
#   Costo total: 48.54
#
# 🔄 Iteración 8 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(12), np.int64(17), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(18), np.int64(19), 20]]
#   Costo total: 49.28
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(15), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(12), np.int64(17), 20], [20, np.int64(6), np.int64(7), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(14), np.int64(11), 20]]
#   Costo total: 49.81
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(12), np.int64(17), 20], [20, np.int64(9), np.int64(19), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 48.62
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(10), np.int64(13), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(9), np.int64(18), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 48.46
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(6), np.int64(19), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.08
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(12), np.int64(17), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(19), np.int64(18), 20]]
#   Costo total: 49.28
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(12), np.int64(18), 20], [20, np.int64(9), np.int64(19), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 49.51
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(17), np.int64(18), 20]]
#   Costo total: 48.35
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(7), np.int64(11), 20]]
#   Costo total: 48.45
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(2), np.int64(19), 20], [20, np.int64(6), np.int64(11), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(17), np.int64(18), 20]]
#   Costo total: 49.18
#
# 🔄 Iteración 9 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(17), np.int64(18), 20], [20, np.int64(2), np.int64(19), 20]]
#   Costo total: 48.35
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(10), np.int64(13), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(12), np.int64(17), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 49.28
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(9), np.int64(18), 20], [20, np.int64(4), np.int64(16), 20]]
#   Costo total: 48.46
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(2), np.int64(19), 20], [20, np.int64(12), np.int64(18), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(7), np.int64(14), 20]]
#   Costo total: 47.26
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(15), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(19), np.int64(6), 20], [20, np.int64(18), np.int64(7), 20]]
#   Costo total: 50.03
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(10), np.int64(13), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(12), np.int64(18), 20], [20, np.int64(2), np.int64(19), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.87
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(17), 20]]
#   Costo total: 50.49
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(12), np.int64(17), 20], [20, np.int64(19), np.int64(7), 20], [20, np.int64(14), np.int64(18), 20]]
#   Costo total: 52.80
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(6), np.int64(19), 20]]
#   Costo total: 46.87
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(6), np.int64(19), 20], [20, np.int64(9), np.int64(18), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 49.15
#
# 🔄 Iteración 10 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(15), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(12), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.87
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(7), np.int64(19), 20]]
#   Costo total: 50.31
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(9), np.int64(2), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 52.28
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(17), np.int64(18), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(6), np.int64(19), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 48.02
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(17), np.int64(19), 20]]
#   Costo total: 47.49
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(19), np.int64(7), 20], [20, np.int64(6), np.int64(11), 20]]
#   Costo total: 51.14
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(18), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(7), 20], [20, np.int64(12), np.int64(14), 20], [20, np.int64(17), np.int64(2), 20]]
#   Costo total: 53.85
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(19), np.int64(2), 20]]
#   Costo total: 47.38
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.17
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(19), np.int64(6), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(7), np.int64(11), 20]]
#   Costo total: 48.15
#
# 🔄 Iteración 11 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(6), np.int64(7), 20], [20, np.int64(14), np.int64(11), 20], [20, np.int64(17), np.int64(2), 20], [20, np.int64(19), np.int64(18), 20]]
#   Costo total: 50.52
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(0), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(12), np.int64(14), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 51.84
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(2), np.int64(18), 20], [20, np.int64(12), np.int64(14), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 50.85
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(0), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(7), 20]]
#   Costo total: 50.28
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(9), np.int64(18), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(12), np.int64(7), 20], [20, np.int64(2), np.int64(19), 20]]
#   Costo total: 49.98
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(18), np.int64(7), 20], [20, np.int64(19), np.int64(6), 20], [20, np.int64(2), np.int64(14), 20], [20, np.int64(17), np.int64(11), 20]]
#   Costo total: 50.82
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(2), np.int64(19), 20]]
#   Costo total: 47.79
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(6), 20], [20, np.int64(12), np.int64(17), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(18), np.int64(11), 20]]
#   Costo total: 48.99
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(2), np.int64(1), 20], [20, np.int64(12), np.int64(17), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(7), 20], [20, np.int64(14), np.int64(6), 20]]
#   Costo total: 48.64
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.38
#
# 🔄 Iteración 12 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(19), np.int64(2), 20]]
#   Costo total: 47.79
#
# 🚚 Ruta 2:
# ...
#   Costo total: 47.17
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(17), np.int64(7), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(11), np.int64(14), 20]]
#   Costo total: 47.88
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(7), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(14), np.int64(18), 20]]
#   Costo total: 48.67
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(7), np.int64(18), 20]]
#   Costo total: 47.34
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(18), 20]]
#   Costo total: 47.32
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(18), 20]]
#   Costo total: 47.32
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(12), np.int64(2), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(7), np.int64(11), 20]]
#   Costo total: 48.55
#
# 🔄 Iteración 98 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(17), np.int64(11), 20], [20, np.int64(9), np.int64(14), 20], [20, np.int64(12), np.int64(2), 20], [20, np.int64(15), np.int64(7), 20], [20, np.int64(19), np.int64(18), 20]]
#   Costo total: 49.97
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(11), np.int64(14), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(7), np.int64(18), 20]]
#   Costo total: 48.03
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(0), np.int64(18), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(11), np.int64(6), 20]]
#   Costo total: 50.75
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(18), 20]]
#   Costo total: 47.32
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(12), np.int64(14), 20], [20, np.int64(7), np.int64(18), 20]]
#   Costo total: 48.90
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(7), np.int64(18), 20]]
#   Costo total: 47.34
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(12), np.int64(18), 20], [20, np.int64(11), np.int64(7), 20]]
#   Costo total: 48.54
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(17), np.int64(7), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(12), np.int64(2), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(11), np.int64(14), 20]]
#   Costo total: 47.98
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(0), np.int64(18), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(11), np.int64(6), 20]]
#   Costo total: 50.75
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(4), np.int64(16), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(15), np.int64(17), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(7), np.int64(14), 20]]
#   Costo total: 47.72
#
# 🔄 Iteración 99 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(0), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(15), np.int64(6), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(17), np.int64(18), 20]]
#   Costo total: 48.35
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(12), np.int64(2), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.48
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(12), np.int64(18), 20]]
#   Costo total: 47.87
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(11), np.int64(6), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(7), np.int64(18), 20]]
#   Costo total: 49.20
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.38
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(6), np.int64(18), 20]]
#   Costo total: 47.38
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(7), np.int64(14), 20]]
#   Costo total: 47.79
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(15), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(17), np.int64(7), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(12), np.int64(2), 20], [20, np.int64(11), np.int64(14), 20], [20, np.int64(19), np.int64(18), 20]]
#   Costo total: 47.98
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(12), np.int64(2), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(11), np.int64(6), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(7), np.int64(1), 20]]
#   Costo total: 50.81
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(15), np.int64(11), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20]]
#   Costo total: 47.38
#
# 🔄 Iteración 100 🔄
#
# 🚚 Ruta 1:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(14), np.int64(7), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20]]
#   Costo total: 47.38
#
# 🚚 Ruta 2:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(17), np.int64(14), 20], [20, np.int64(7), np.int64(1), 20], [20, np.int64(6), np.int64(2), 20]]
#   Costo total: 48.39
#
# 🚚 Ruta 3:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(12), np.int64(2), 20], [20, np.int64(11), np.int64(14), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(7), np.int64(17), 20]]
#   Costo total: 47.98
#
# 🚚 Ruta 4:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(11), np.int64(14), 20], [20, np.int64(17), np.int64(7), 20], [20, np.int64(6), np.int64(2), 20]]
#   Costo total: 47.42
#
# 🚚 Ruta 5:
#   Vehículo 1.0 - Rutas: [[20, np.int64(4), np.int64(16), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.38
#
# 🚚 Ruta 6:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(6), np.int64(18), 20], [20, np.int64(11), np.int64(17), 20], [20, np.int64(19), np.int64(2), 20], [20, np.int64(14), np.int64(7), 20]]
#   Costo total: 47.17
#
# 🚚 Ruta 7:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(6), np.int64(7), 20], [20, np.int64(14), np.int64(2), 20]]
#   Costo total: 52.51
#
# 🚚 Ruta 8:
#   Vehículo 1.0 - Rutas: [[20, np.int64(8), np.int64(5), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(15), np.int64(11), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(6), np.int64(2), 20]]
#   Costo total: 46.92
#
# 🚚 Ruta 9:
#   Vehículo 1.0 - Rutas: [[20, np.int64(11), np.int64(14), 20], [20, np.int64(0), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(15), np.int64(12), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(9), np.int64(17), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(7), np.int64(18), 20], [20, np.int64(19), np.int64(2), 20]]
#   Costo total: 48.03
#
# 🚚 Ruta 10:
#   Vehículo 1.0 - Rutas: [[20, np.int64(4), np.int64(16), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(8), np.int64(5), 20], [20, np.int64(0), np.int64(17), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(6), np.int64(1), 20], [20, np.int64(9), np.int64(11), 20], [20, np.int64(12), np.int64(2), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(7), np.int64(14), 20]]
#   Costo total: 47.89
#
# ✅ Mejor solución encontrada:
# [(np.float64(1.0), [[20, np.int64(8), np.int64(5), 20], [20, np.int64(12), np.int64(1), 20], [20, np.int64(15), np.int64(3), 20], [20, np.int64(10), np.int64(13), 20], [20, np.int64(0), np.int64(9), 20], [20, np.int64(4), np.int64(16), 20], [20, np.int64(7), np.int64(14), 20], [20, np.int64(11), np.int64(17), 20], [20, np.int64(19), np.int64(18), 20], [20, np.int64(6), np.int64(2), 20]])]
# 💰 Mejor precio: 46.71

# %%
file_path = "../../Datos_P1/df_location.xlsx"  # Asegúrate de colocar tu archivo Excel aquí
df = pd.read_excel(file_path)

# Asegurar que las columnas sean correctas
df.columns = df.columns.str.strip()

coordenadas_clientes = {
    int(row["Cliente"].replace("Cliente_", "")) - 1: (row["Latitud"], row["Longitud"])
    for _, row in df.iterrows() if isinstance(row["Cliente"], str) and "Cliente_" in row["Cliente"]
}

# Agregar el almacén con clave 20
almacen = df[df["Cliente"] == "Almacén"][["Latitud", "Longitud"]].values
if len(almacen) > 0:
    coordenadas_clientes[20] = tuple(almacen[0])  

# El almacen es el centro del mapa
start_location = coordenadas_clientes.get(20, list(coordenadas_clientes.values())[0])
m = folium.Map(location=start_location, zoom_start=13)

resultado = solucion_optima
if resultado is None:
    raise ValueError("La función ACO devolvió None")
rutas = resultado


# Dibujar rutas en el mapa
for vehiculo, rutas_por_vehiculo in rutas:
    for ruta in rutas_por_vehiculo:
        ruta = [cliente for cliente in ruta if cliente != 0]  # REVISION
        coordenadas = [coordenadas_clientes.get(cliente, start_location) for cliente in ruta]

        # Color aleatorio por ruta
        color = "#{:06x}".format(random.randint(0, 0xFFFFFF))
        folium.PolyLine(coordenadas, color=color, weight=2.5, opacity=0.8).add_to(m)

# Agregar marcadores de clientes y almacén
for cliente, coords in coordenadas_clientes.items():
    if cliente == 20:
        nombre = "Almacén"
        color = "red"  # Rojo para el almacén
    else:
        nombre = f"Cliente {cliente + 1}"  # Sumamos 1 solo para la visualización
        color = "blue"  # Azul para clientes
    
    folium.Marker(
        location=coords,
        popup=nombre,
        icon=folium.Icon(color=color, icon="info-sign"),
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_511a3c2a0733cfb3fe4fc48f40212e5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_511a3c2a0733cfb3fe4fc48f40212e5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_511a3c2a0733cfb3fe4fc48f40212e5d = L.map(
#                 &quot;map_511a3c2a0733cfb3fe4fc48f40212e5d&quot;,
#                 {
#                     center: [40.3885963, -3.7270384],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f801c0cc981a992a79a3f51b60ac2db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f801c0cc981a992a79a3f51b60ac2db.addTo(map_511a3c2a0733cfb3fe4fc48f40212e5d);
#
#
#             var poly_line_0b4eb11f227d0d5e72d49bfb8d1f6b5b = L.polyline(
#                 [[40.3885963, -3.7270384], [40.3896366, -3.7353538], [40.4004807, -3.712361], [40.3885963, -3.7270384]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#5ce45d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#5ce45d&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_511a3c2a0733cfb3fe4fc48f40212e5d);
#
#
#             var poly_line_54d016b8a4b5e5ef0169c6590503b5b8 = L.polyline(
#                 [[40.3885963, -3.7270384], [40.4343313, -3.7045345], [40.4558202, -3.7003498], [40.3885963, -3.7270384]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e5bd9b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#e5bd9b&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_511a3c2a0733cfb3fe4fc48f40212e5d);
#
#
#             var poly_line_1747a0856806a73d3a61e8c8dd065b78 = L.polyline(
#                 [[40.3885963, -3.7270384], [40.4061912, -3.6988754], [40.4046876, -3.7062622], [40.3885963, -3.7270384]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#535a55&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#535a55&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_511a3c2a0733cfb3fe4fc48f40212e5d);
#
#
#             var poly_line_eb11ede56b2e062410dde55051f09a2f = L.polyline(
#                 [[40.3885963, -3.7270384], [40.3893878, -3.7004158], [40.3862643, -3.6908621], [40.3885963, -3.7270384]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f2a671&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#f2a671&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_511a3c2a0733cfb3fe4fc48f40212e5d);
#
#
#             var poly_line_7b83852d8bd645aafd9faa6fc2398e73 = L.polyline(
#                 [[40.3885963, -3.7270384], [40.4090831, -3.676125], [40.3885963, -3.7270384]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#48cec7&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#48cec7&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_511a3c2a0733cfb3fe4fc48f40212e5d);
#
#
#             var poly_line_8a3e691efbbc88534b8d21e779896efa = L.polyline(
#                 [[40.3885963, -3.7270384], [40.3719903, -3.6950556], [40.3340239, -3.7118486], [40.3885963, -3.7270384]],
#                 {&quot;bubblingMouseEve
